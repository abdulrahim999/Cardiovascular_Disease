# %%
# strat my project by importing all libarirys I need for now

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
pwd
# Out:
# 'C:\\Users\\Abdulrahim'

# %%
# lodaing my data which is cardio

df = pd.read_csv("cardio.csv" , sep=";")

df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
# we remove ID colmen

df = df.drop('id', axis=1)
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# we have the age callculated in dayes and flot
# we want to convert it in years with round up to be int

df.age.describe()
# Out:
# count    70000.000000
# mean     19468.865814
# std       2467.251667
# min      10798.000000
# 25%      17664.000000
# 50%      19703.000000
# 75%      21327.000000
# max      23713.000000
# Name: age, dtype: float64

# %%
df["age"] = round(df["age"] / 365)
df
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      50.0       2     168    62.0    110     80            1     1      0
# 1      55.0       1     156    85.0    140     90            3     1      0
# 2      52.0       1     165    64.0    130     70            3     1      0
# 3      48.0       2     169    82.0    150    100            1     1      0
# 4      48.0       1     156    56.0    100     60            1     1      0
# ...     ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  53.0       2     168    76.0    120     80            1     1      1
# 69996  62.0       1     158   126.0    140     90            2     2      0
# 69997  52.0       2     183   105.0    180     90            3     1      0
# 69998  61.0       1     163    72.0    135     80            1     2      0
# 69999  56.0       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.338686      1.349571    164.359229     74.205690    128.817286
# std        6.765294      0.476838      8.210126     14.395757    154.011419
# min       30.000000      1.000000     55.000000     10.000000   -150.000000
# 25%       48.000000      1.000000    159.000000     65.000000    120.000000
# 50%       54.000000      1.000000    165.000000     72.000000    120.000000
# 75%       58.000000      2.000000    170.000000     82.000000    140.000000
# max       65.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# ...

# %%
# to minimies the zeroes after the comma .0000000
pd.set_option('display.float_format',lambda x:'%.2f'% x)

# %%
df.describe()
# Out:
#            age   gender   height   weight    ap_hi    ap_lo  cholesterol  \
# count 70000.00 70000.00 70000.00 70000.00 70000.00 70000.00     70000.00
# mean     53.34     1.35   164.36    74.21   128.82    96.63         1.37
# std       6.77     0.48     8.21    14.40   154.01   188.47         0.68
# min      30.00     1.00    55.00    10.00  -150.00   -70.00         1.00
# 25%      48.00     1.00   159.00    65.00   120.00    80.00         1.00
# 50%      54.00     1.00   165.00    72.00   120.00    80.00         1.00
# 75%      58.00     2.00   170.00    82.00   140.00    90.00         2.00
# max      65.00     2.00   250.00   200.00 16020.00 11000.00         3.00
#
#           gluc    smoke     alco   active   cardio
# count 70000.00 70000.00 70000.00 70000.00 70000.00
# mean      1.23     0.09     0.05     0.80     0.50
# std       0.57     0.28     0.23     0.40     0.50
# min       1.00     0.00     0.00     0.00     0.00
# 25%       1.00     0.00     0.00     1.00     0.00
# ...

# %%
# we found outlyer in ap_hi with max 16020 and min -150  so we have to fix this issue with to be in the range of 108 and 200

df['ap_hi']  = df['ap_hi'].apply(lambda x: (np.nan if x <= 108 else x))
df['ap_hi']  = df['ap_hi'].apply(lambda x: (np.nan if x >= 200 else x))

# %%
df.describe()
# Out:
#            age   gender   height   weight    ap_hi    ap_lo  cholesterol  \
# count 70000.00 70000.00 70000.00 70000.00 65739.00 70000.00     70000.00
# mean     53.34     1.35   164.36    74.21   128.57    96.63         1.37
# std       6.77     0.48     8.21    14.40    15.35   188.47         0.68
# min      30.00     1.00    55.00    10.00   109.00   -70.00         1.00
# 25%      48.00     1.00   159.00    65.00   120.00    80.00         1.00
# 50%      54.00     1.00   165.00    72.00   120.00    80.00         1.00
# 75%      58.00     2.00   170.00    82.00   140.00    90.00         2.00
# max      65.00     2.00   250.00   200.00   199.00 11000.00         3.00
#
#           gluc    smoke     alco   active   cardio
# count 70000.00 70000.00 70000.00 70000.00 70000.00
# mean      1.23     0.09     0.05     0.80     0.50
# std       0.57     0.28     0.23     0.40     0.50
# min       1.00     0.00     0.00     0.00     0.00
# 25%       1.00     0.00     0.00     1.00     0.00
# ...

# %%
# from the describe we found that ap_lo  have outlyer with max 11000 and min -70 we clean this with the range of 76 and 130

df['ap_lo']  = df['ap_lo'].apply(lambda x: (np.nan if x <= 76 else x))
df['ap_lo']  = df['ap_lo'].apply(lambda x: (np.nan if x >= 130 else x))

# %%
df.describe()
# Out:
#            age   gender   height   weight    ap_hi    ap_lo  cholesterol  \
# count 70000.00 70000.00 70000.00 70000.00 65739.00 55236.00     70000.00
# mean     53.34     1.35   164.36    74.21   128.57    84.61         1.37
# std       6.77     0.48     8.21    14.40    15.35     7.04         0.68
# min      30.00     1.00    55.00    10.00   109.00    77.00         1.00
# 25%      48.00     1.00   159.00    65.00   120.00    80.00         1.00
# 50%      54.00     1.00   165.00    72.00   120.00    80.00         1.00
# 75%      58.00     2.00   170.00    82.00   140.00    90.00         2.00
# max      65.00     2.00   250.00   200.00   199.00   126.00         3.00
#
#           gluc    smoke     alco   active   cardio
# count 70000.00 70000.00 70000.00 70000.00 70000.00
# mean      1.23     0.09     0.05     0.80     0.50
# std       0.57     0.28     0.23     0.40     0.50
# min       1.00     0.00     0.00     0.00     0.00
# 25%       1.00     0.00     0.00     1.00     0.00
# ...

# %%
# from the describe we found that ap_lo  have outlyer with max 250 and min 8,21 we clean this with the range of 150 and 190

df['height']  = df['height'].apply(lambda x: (np.nan if x <= 150 else x))
df['height']  = df['height'].apply(lambda x: (np.nan if x >= 190 else x))

# %%
df.describe()
# Out:
#            age   gender   height   weight    ap_hi    ap_lo  cholesterol  \
# count 70000.00 70000.00 67307.00 70000.00 65739.00 55236.00     70000.00
# mean     53.34     1.35   165.01    74.21   128.57    84.61         1.37
# std       6.77     0.48     7.20    14.40    15.35     7.04         0.68
# min      30.00     1.00   151.00    10.00   109.00    77.00         1.00
# 25%      48.00     1.00   160.00    65.00   120.00    80.00         1.00
# 50%      54.00     1.00   165.00    72.00   120.00    80.00         1.00
# 75%      58.00     2.00   170.00    82.00   140.00    90.00         2.00
# max      65.00     2.00   189.00   200.00   199.00   126.00         3.00
#
#           gluc    smoke     alco   active   cardio
# count 70000.00 70000.00 70000.00 70000.00 70000.00
# mean      1.23     0.09     0.05     0.80     0.50
# std       0.57     0.28     0.23     0.40     0.50
# min       1.00     0.00     0.00     0.00     0.00
# 25%       1.00     0.00     0.00     1.00     0.00
# ...

# %%
# from the describe we found that ap_lo  have outlyer with max 200 and min 11 we clean this with the range of 50 and 140

df['weight']  = df['weight'].apply(lambda x: (np.nan if x <= 50 else x))
df['weight']  = df['weight'].apply(lambda x: (np.nan if x >= 140 else x))

# %%
df.describe()
# Out:
#            age   gender   height   weight    ap_hi    ap_lo  cholesterol  \
# count 70000.00 70000.00 67307.00 68396.00 65739.00 55236.00     70000.00
# mean     53.34     1.35   165.01    74.66   128.57    84.61         1.37
# std       6.77     0.48     7.20    13.56    15.35     7.04         0.68
# min      30.00     1.00   151.00    50.50   109.00    77.00         1.00
# 25%      48.00     1.00   160.00    65.00   120.00    80.00         1.00
# 50%      54.00     1.00   165.00    72.00   120.00    80.00         1.00
# 75%      58.00     2.00   170.00    82.00   140.00    90.00         2.00
# max      65.00     2.00   189.00   139.00   199.00   126.00         3.00
#
#           gluc    smoke     alco   active   cardio
# count 70000.00 70000.00 70000.00 70000.00 70000.00
# mean      1.23     0.09     0.05     0.80     0.50
# std       0.57     0.28     0.23     0.40     0.50
# min       1.00     0.00     0.00     0.00     0.00
# 25%       1.00     0.00     0.00     1.00     0.00
# ...

# %%
# we have the gender female reprsntitive 1 and male by 2

# we can convert it to male and female insted of 2,1

# we will use this outcome in our statices 

df.gender.value_counts()
# Out:
# 1    45530
# 2    24470
# Name: gender, dtype: int64

# %%
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0 50.00       2  168.00   62.00 110.00  80.00            1     1      0     0
# 1 55.00       1  156.00   85.00 140.00  90.00            3     1      0     0
# 2 52.00       1  165.00   64.00 130.00    NaN            3     1      0     0
# 3 48.00       2  169.00   82.00 150.00 100.00            1     1      0     0
# 4 48.00       1  156.00   56.00    NaN    NaN            1     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 2       0       1
# 3       1       1
# 4       0       0

# %%
# after we cleaining the ap_hi and ap_lo NaN appeared so we will fix it by dropan methoed
df.dropna(subset = ["ap_lo"], inplace =True)

# %%
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0 50.00       2  168.00   62.00 110.00  80.00            1     1      0     0
# 1 55.00       1  156.00   85.00 140.00  90.00            3     1      0     0
# 3 48.00       2  169.00   82.00 150.00 100.00            1     1      0     0
# 5 60.00       1  151.00   67.00 120.00  80.00            2     2      0     0
# 6 61.00       1  157.00   93.00 130.00  80.00            3     1      0     0
#
#    active  cardio
# 0       1       0
# 1       1       1
# 3       1       1
# 5       0       0
# 6       1       0

# %%
df["gender"].replace({1: "female", 2: "male"}, inplace=True)
print(df)
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0     50.00    male  168.00   62.00 110.00  80.00            1     1      0
# 1     55.00  female  156.00   85.00 140.00  90.00            3     1      0
# 3     48.00    male  169.00   82.00 150.00 100.00            1     1      0
# 5     60.00  female  151.00   67.00 120.00  80.00            2     2      0
# 6     61.00  female  157.00   93.00 130.00  80.00            3     1      0
# ...     ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995 53.00    male  168.00   76.00 120.00  80.00            1     1      1
# 69996 62.00  female  158.00  126.00 140.00  90.00            2     2      0
# 69997 52.00    male  183.00  105.00 180.00  90.00            3     1      0
# 69998 61.00  female  163.00   72.00 135.00  80.00            1     2      0
# 69999 56.00  female  170.00   72.00 120.00  80.00            2     1      0
#
#        alco  active  cardio
# ...

# %% [markdown]
# # study show how much smoker and non smoker along with gender

# %%
sb.countplot(x='gender', data=df, hue='smoke')
plt.savefig('1.png')
plt.show()

# %% [markdown]
# # study show how much having cardiovascular along with gender

# %%
sb.countplot(x='gender', data=df, hue='cardio')
plt.savefig('2.png')
plt.show()

# %% [markdown]
# # study show the relationship between smoker and non smoker along with cardiovascular

# %%
sb.countplot(x='smoke', data=df, hue='cardio')
plt.savefig('3.png')
plt.show()

# %% [markdown]
# # study show the relationship between the age and cardiovascular

# %%
plt.figure(figsize = [10,10])
plt.xticks(rotation=90);
sb.countplot(x='age', data=df, hue='cardio') 
plt.savefig('4.png')

plt.show()

# %% [markdown]
# # study show the relationship between the age and cholesterol

# %%
plt.figure(figsize = [10,10])
plt.xticks(rotation=90);
sb.countplot(x='age', data=df, hue='cholesterol') 
plt.savefig('5.png')

plt.show()

# %% [markdown]
# # study show the relationship between the cardiovascular and cholesterol

# %%
plt.figure(figsize = [10,10])
plt.xticks(rotation=90);
sb.countplot(x='cardio', data=df, hue='cholesterol')
plt.savefig('6.png')

plt.show()

# %% [markdown]
# # study show the relationship between smoker and non smkoer along with cholesterol

# %%
plt.figure(figsize = [10,10])
plt.xticks(rotation=90);
sb.countplot(x='smoke', data=df, hue='cholesterol')
plt.savefig('7.png')

plt.show()
